# %%
import rioxarray

# %%
rgb_stack_HARV = rioxarray.open_rasterio("E:/geospatial-python/material/exercise_1/Image.tif")

# %%
print(rgb_stack_HARV)
# Out:
# <xarray.DataArray (band: 4, y: 940, x: 766)>
# [2880160 values with dtype=float64]
# Coordinates:
#   * band         (band) int32 1 2 3 4
#   * x            (x) float64 4.082e+05 4.082e+05 4.082e+05 ... 4.09e+05 4.09e+05
#   * y            (y) float64 4.606e+06 4.606e+06 ... 4.605e+06 4.605e+06
#     spatial_ref  int32 0
# Attributes:
#     RepresentationType:  ATHEMATIC
#     _FillValue:          0.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
print(type(rgb_stack_HARV))
print(rgb_stack_HARV.shape)
print(rgb_stack_HARV.values)
# Out:
# <class 'xarray.core.dataarray.DataArray'>
# (4, 940, 766)
# [[[113. 111. 126. ...  95.  92. 104.]
#   [116. 114. 136. ...  88.  80.  88.]
#   [120. 103. 105. ...  82. 110.  85.]
#   ...
#   [ 81.  78.  63. ...  61.  61.  64.]
#   [ 71.  66.  62. ...  74.  72.  56.]
#   [ 73.  72.  66. ...  52.  58.  42.]]
#
#  [[152. 152. 153. ... 130. 128. 130.]
#   [145. 152. 157. ... 127. 125. 131.]
#   [146. 132. 127. ... 123. 136. 123.]
#   ...
#   [105. 106. 101. ...  86.  94. 105.]
#   [105. 106.  94. ... 110.  94.  80.]
#   [110. 111.  97. ...  94.  85.  67.]]
#
#  [[101. 100. 103. ...  74.  74.  78.]
#   [ 97. 101. 114. ...  71.  71.  64.]
#   [103.  97. 100. ...  67.  90.  70.]
#   ...
#   [ 71.  76.  71. ...  60.  61.  62.]
#   [ 72.  71.  65. ...  69.  65.  55.]
#   [ 72.  76.  72. ...  56.  57.  45.]]
#
#  [[192. 198. 199. ... 160. 164. 175.]
#   [192. 190. 173. ... 174. 176. 178.]
#   [161. 154. 140. ... 175. 184. 195.]
#   ...
#   [189. 187. 191. ... 184. 172. 162.]
#   [195. 194. 188. ... 183. 176. 137.]
#   [192. 198. 191. ... 150. 144. 127.]]]

# %%
print(rgb_stack_HARV.coords)
# Out:
# Coordinates:
#   * band         (band) int32 1 2 3 4
#   * x            (x) float64 4.082e+05 4.082e+05 4.082e+05 ... 4.09e+05 4.09e+05
#   * y            (y) float64 4.606e+06 4.606e+06 ... 4.605e+06 4.605e+06
#     spatial_ref  int32 0

# %%
print(rgb_stack_HARV.attrs)
# Out:
# {'RepresentationType': 'ATHEMATIC', '_FillValue': 0.0, 'scale_factor': 1.0, 'add_offset': 0.0}

# %%
print(rgb_stack_HARV.rio.crs)
print(rgb_stack_HARV.rio.nodata)
print(rgb_stack_HARV.rio.bounds())
print(rgb_stack_HARV.rio.width)
print(rgb_stack_HARV.rio.height)
# Out:
# PROJCS["UTM_Zone_15_Northern_Hemisphere",GEOGCS["GCS_GRS_1980_IUGG_1980",DATUM["D_unknown",SPHEROID["GRS80",6378137,298.257222101]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-93],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# 0.0
# (408244.0, 4604726.0, 409010.0, 4605666.0)
# 766
# 940

# %%
rgb_band1_HARV = rgb_stack_HARV.sel(band=1)
rgb_band1_HARV
# Out:
# <xarray.DataArray (y: 940, x: 766)>
# array([[113., 111., 126., ...,  95.,  92., 104.],
#        [116., 114., 136., ...,  88.,  80.,  88.],
#        [120., 103., 105., ...,  82., 110.,  85.],
#        ...,
#        [ 81.,  78.,  63., ...,  61.,  61.,  64.],
#        [ 71.,  66.,  62., ...,  74.,  72.,  56.],
#        [ 73.,  72.,  66., ...,  52.,  58.,  42.]])
# Coordinates:
#     band         int32 1
#   * x            (x) float64 4.082e+05 4.082e+05 4.082e+05 ... 4.09e+05 4.09e+05
#   * y            (y) float64 4.606e+06 4.606e+06 ... 4.605e+06 4.605e+06
#     spatial_ref  int32 0
# Attributes:
#     RepresentationType:  ATHEMATIC
#     _FillValue:          0.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
rgb_band1_HARV.plot.imshow(figsize=(9,7), cmap="Greys")

# %%
rgb_band2_HARV = rgb_stack_HARV.sel(band=2)
rgb_band2_HARV
# Out:
# <xarray.DataArray (y: 940, x: 766)>
# array([[152., 152., 153., ..., 130., 128., 130.],
#        [145., 152., 157., ..., 127., 125., 131.],
#        [146., 132., 127., ..., 123., 136., 123.],
#        ...,
#        [105., 106., 101., ...,  86.,  94., 105.],
#        [105., 106.,  94., ..., 110.,  94.,  80.],
#        [110., 111.,  97., ...,  94.,  85.,  67.]])
# Coordinates:
#     band         int32 2
#   * x            (x) float64 4.082e+05 4.082e+05 4.082e+05 ... 4.09e+05 4.09e+05
#   * y            (y) float64 4.606e+06 4.606e+06 ... 4.605e+06 4.605e+06
#     spatial_ref  int32 0
# Attributes:
#     RepresentationType:  ATHEMATIC
#     _FillValue:          0.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
rgb_band2_HARV.plot.imshow(figsize=(9,7), cmap="Greys")

# %%
rgb_band3_HARV = rgb_stack_HARV.sel(band=3)
rgb_band3_HARV
# Out:
# <xarray.DataArray (y: 940, x: 766)>
# array([[101., 100., 103., ...,  74.,  74.,  78.],
#        [ 97., 101., 114., ...,  71.,  71.,  64.],
#        [103.,  97., 100., ...,  67.,  90.,  70.],
#        ...,
#        [ 71.,  76.,  71., ...,  60.,  61.,  62.],
#        [ 72.,  71.,  65., ...,  69.,  65.,  55.],
#        [ 72.,  76.,  72., ...,  56.,  57.,  45.]])
# Coordinates:
#     band         int32 3
#   * x            (x) float64 4.082e+05 4.082e+05 4.082e+05 ... 4.09e+05 4.09e+05
#   * y            (y) float64 4.606e+06 4.606e+06 ... 4.605e+06 4.605e+06
#     spatial_ref  int32 0
# Attributes:
#     RepresentationType:  ATHEMATIC
#     _FillValue:          0.0
#     scale_factor:        1.0
#     add_offset:          0.0

# %%
rgb_band3_HARV.plot.imshow(figsize=(9,7), cmap="Greys")

# %%
rgb_stack_HARV.plot.imshow(figsize=(9,7), robust=True)
