# %%
import geopandas as gpd

# %%
lines_HARV = gpd.read_file("E:/geospatial-python/material/exercise_1/clippedRefinedLines.shp")

# %%
lines_HARV.columns
# Out:
# Index(['Id', 'geometry'], dtype='object')

# %%
lines_HARV.Id
# Out:
# 0    0
# 1    0
# 2    0
# Name: Id, dtype: int64

# %%
lines_HARV.geometry
# Out:
# 0    LINESTRING (-94.09519 41.59739, -94.09519 41.5...
# 1    LINESTRING (-94.09537 41.59445, -94.09543 41.5...
# 2    LINESTRING (-94.09537 41.59445, -94.09535 41.5...
# Name: geometry, dtype: geometry

# %%
LINESTRING_HARV = lines_HARV[lines_HARV.type == "LINESTRING"]
len(LINESTRING_HARV)
# Out:
# 0

# %%
lines_HARV.plot(figsize=(5,5), edgecolor="brown", facecolor="green")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
lines_HARV.plot(column="Id", linewidth=3, legend=True, figsize=(16,10))
# Out:
# <AxesSubplot:>
